# %%
#Create a directory in Desktop named “python_files”, then a subdirectory as “week5”.
#Then put the “train_titanic.csv” there
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
import os
os.getcwd()# get current directory
# Out:
# 'C:\\Users\\SepehrRayan\\Desktop\\python_files\\week5'

# %%
os.chdir('C:\\Users\\SepehrRayan\\Desktop\\python_files\\week5')

# %%
df = pd.read_csv('train_titanic.csv')# read csv file 
df.head()#show its 5th attributes
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Show info, and describe the data frame.
df.info()
print("\n EXPLANATION: our data frame shown here consists of 12 columns(entity) and 891 its related values (property). columns have all \n not-null values with different data types.2 columns have integer,5 have float valuse and 5 columns are objects")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
#
#  EXPLANATION: our data frame shown here consists of 12 columns(entity) and 891 its related values (property). columns have all
#  not-null values with different data types consisting of 2 int columns,5 float columns and 5 columns objects

# %%
#Drop the row with index 1
df_drop=df.drop(1)# specify coulumn which would like to drop,here 1.
df_drop.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
#Drop the column called “Embarked”
df_drop2=df.drop(['Embarked'], axis=1) #Put index=1 to drop a column with the name of it
df_drop2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN

# %%
#Drop rows with null values
df.dropna(axis=0, how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
#Plot fare histogram
df_clo_fair = df.loc[: , "Fare"]#extract coulumn named fare
print(df_clo_fair)
#df['fare']
plt.hist(df_clo_fair,8)#print its histogram
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 861     11.5000
# 862     25.9292
# 863     69.5500
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# ...

# %%
#Plot survived histogram
df_clo_survived = df.loc[: , "Survived"]
print(df_clo_survived)
plt.hist(df_clo_fair,4)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# (array([853.,  29.,   6.,   3.]),
#  array([  0.    , 128.0823, 256.1646, 384.2469, 512.3292]),
#  <a list of 4 Patch objects>)

# %%
#Draw correlation matrix
# Create and print correlation matrix:
corr = df.corr()
print(corr)
corr.style.background_gradient(cmap='coolwarm')# customize the output
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000
# <style  type="text/css" >
#     #T_c0363f86_fc0d_11e9_9693_70f395d73bferow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
# ...

# %%
#Interpret your results and print your text as output
interpret=open("interpretation.txt","w+")
interpret.write("correlation is a rectangular matrix in range of -1 to 1 that shows the relationship between the two values./npositive correlation indicates that improvement of one value causes the improvement of the other. for instance,/nhere, SibSp has a fairly good relation with Parch and increasement of one increses the other one")
interpret.close()
