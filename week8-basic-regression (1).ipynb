# %%
# QUESTION1:Run the script discussed in class and generate the answers we went over.
# I installed necessary libraries and see the result, hopefully have not any problem

# %%
#question2
#"refactor" your plotting code to work on the dataset as loaded by from sklearn.datasetsimport 
#load_{yourdatasetname}.
#Use any database you are more familiar when you weredoing EDA and Visualization

# %%
# I want to work on diabete dataset. firstly I read data and do EDA
#Reading data & checking top few data rows

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

df = pd.read_csv('/Users/ameneh/Downloads/diabetes.data',
                 sep='\s+',
                 header=0)


df.tail(10)

# %%
#Lets select all features to explore more.if we have many features we should select some of them.here I consider all
df = df[['AGE','SEX','BMI','BP','S1','S2','S3','S4','S5','S6','Y']]
df.head(9)
df.hist()
plt.show()

# %%
# I want to predict BMI through simple linear regression. so I am trying to see if there is any linear relation 
#between this column and rest of columns
plt.scatter(df.AGE, df.BMI,  color='blue')
plt.xlabel("AGE")
plt.ylabel("BMI")
plt.show()

# %%
plt.scatter(df.BP, df.BMI,  color='blue')
plt.xlabel("BP")
plt.ylabel("BMI")
plt.show()

# %%
plt.scatter(df.BP, df.BMI,  color='blue')
plt.xlabel("S1")
plt.ylabel("BMI")
plt.show()

# %%
plt.scatter(df.BP, df.BMI,  color='blue')
plt.xlabel("S2")
plt.ylabel("BMI")
plt.show()

# %%
plt.scatter(df.BP, df.BMI,  color='blue')
plt.xlabel("S3")
plt.ylabel("BMI")
plt.show()

# %%
# I have planed to delete outliers, however, I postponed it to search more as I need more clarification.but I keep 
#the code
#from scipy import stats
#import numpy as np
#z = np.abs(stats.zscore(df))
#print(z)

# %%
#threshold = 3
#print(np.where(z > 3))

# %%
#df_o = df[(z < 3).all(axis=1)]
#df.info()
#df_o.info()

# %%
plt.scatter(df.Y, df.BMI, color='blue')
plt.xlable("Y")
plt.ylabel("BMI")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-464541a0a8a4> in <module>
#       1 plt.scatter(df.Y, df.BMI, color='blue')
# ----> 2 plt.xlable("Y")
#       3 plt.ylabel("BMI")
#       4 plt.show()
#       5
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
plt.scatter(train.BMI, train.Y,  color='blue')
plt.xlabel("Y")
plt.ylabel("BMI")
plt.show()
#COLUMN Y LOOKS LIKE TO HAVE A LINEAR RELATION WITH BMI. LET'S USE LINEAR REGRESSION AND SEE THE RESULT

# %%
#split the columns randomly to the test and train column.80% of data for the train and 20% for the test
df_t= np.random.rand(len(df)) < 0.8
train = df[df_t]
test = df[~df_t]

# %%
#use linear regression method
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['Y']])# OUR INDEPENDENT TRAIN SET
train_y = np.asanyarray(train[['BMI']])# DEPENDENT TEST SET
regr.fit (train_x, train_y)
# The coefficients AND INTERCEPT OF LINE
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.03203571]]
# Intercept:  [21.38373643]

# %%
#test the model
from sklearn.metrics import r2_score
test_x = np.asanyarray(test[['Y']])
test_y = np.asanyarray(test[['BMI']])
test_y_ = regr.predict(test_x)
#see the result. MSE is not too high, it doe not sound to have a bad result
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_ , test_y))
# Out:
# Mean absolute error: 2.83
# Residual sum of squares (MSE): 11.92
# R2-score: -1.39

# %%
#QUESTION 3:
#perform classification/regression on your dataset using Linear regression/Logisticregression, as applicable, and 
#print performance. You need to define the target (i.e,y-value for regression and labeling for classification

# %%
#Now I want to answer another question using the same dataset
#how much BP goes up (down)in every unit increase(decrease) on BMI
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['AGE', 'BP'])

# %%
import os
os.getcwd()
os.chdir('/Users/ameneh/Downloads')

# %%
#import packages
import pandas as pd
import numpy as np

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline

#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#read the file

df = pd.read_csv('/Users/ameneh/Downloads/diabetes.data',
                 sep='\s+',
                 header=0)

#print the head
df.head()
#df.info()
# Out:
#    AGE  SEX   BMI     BP   S1     S2    S3   S4      S5  S6    Y
# 0   59    2  32.1  101.0  157   93.2  38.0  4.0  4.8598  87  151
# 1   48    1  21.6   87.0  183  103.2  70.0  3.0  3.8918  69   75
# 2   72    2  30.5   93.0  156   93.6  41.0  4.0  4.6728  85  141
# 3   24    1  25.3   84.0  198  131.4  40.0  5.0  4.8903  89  206
# 4   50    1  23.0  101.0  192  125.4  52.0  4.0  4.2905  80  135

# %%
 
#df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
# AGE    442 non-null int64
# SEX    442 non-null int64
# BMI    442 non-null float64
# BP     442 non-null float64
# S1     442 non-null int64
# S2     442 non-null float64
# S3     442 non-null float64
# S4     442 non-null float64
# S5     442 non-null float64
# S6     442 non-null int64
# Y      442 non-null int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
#create a new dataframe consisting of our columns that we want to find their relation.
new_data = pd.DataFrame(index=range(0,len(df)),columns=['BMI', 'BP'])
new_data.head()
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 2 columns):
# BMI    0 non-null object
# BP     0 non-null object
# dtypes: object(2)
# memory usage: 7.0+ KB

# %%
#FILL THE DATAFRAME WITH THEIR VALUES
for i in range(0,len(df)):
     new_data['BMI'][i] = df['BMI'][i]
     new_data['BP'][i] = df['BP'][i]

# %%
#SPLIT THE DATA TO TRAIN AND TEST(VALID)
train = new_data[:360]
valid = new_data[360:]
print('\n Shape of training set:')
print(train.shape)
# Out:
#  Shape of training set:
# (360, 2)

# %%
# shapes of validation set
print('\n Shape of validation set:')
print(valid.shape)

# In the next step, we will create predictions for the validation set and check the RMSE using the actual values.
# making predictions
preds = []
for i in range(0,valid.shape[0]):
    a = train['BP'][len(train)-360+i:].sum() + sum(preds)
    b = a/248
    preds.append(b)

# checking the results (RMSE value)
rms=np.sqrt(np.mean(np.power((np.array(valid['BP'])-preds),2)))
print('\n RMSE value on validation set:')
print(rms)
# Out:
#  Shape of validation set:
# (82, 2)
#
#  RMSE value on validation set:
# 53.82767309157069

# %%
#plot
valid['Predictions'] = 0
valid['Predictions'] = preds
plt.plot(train['BP'])
plt.plot(valid[['BP', 'Predictions']])
# Out:
# /Users/ameneh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/ameneh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...
